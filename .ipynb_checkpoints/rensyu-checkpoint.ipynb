# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://wall.alphacoders.com/by_sub_category.php?id=239594&name=Fate%2FGrand+Order+Wallpapers&page=1')

# %%
soup = BeautifulSoup(response.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2304 Fate/Grand Order HD Wallpapers | Background Images - Wallpaper Abyss </title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="2304 Fate/Grand Order HD Wallpapers and Background Images. Download for free on all your devices - Computer, Smartphone, or Tablet. - Wallpaper Abyss " name="description"/>
# <meta content="wallpaper, background, wallpapers, backgrounds, hd wallpapers, high definition wallpapers, desktop backgrounds, mobile wallpapers, tablet wallpapers, Anime, Fate/Grand Order" name="keywords"/>
# <!-- Schema.org markup for Google+ -->
# <meta content="2304 Fate/Grand Order HD Wallpapers | Background Images" itemprop="name"/>
# ...

# %%
src = soup.findAll('img')
print(src)
# Out:
# [<img alt="English-flag" src="https://static.alphacoders.com/wa/English-flag.png"/>, <img alt="" src="https://static.alphacoders.com/icons/favicon-16x16.png"/>, <img alt="" src="https://static.alphacoders.com/icons/wallpaper/favicon-16x16.png"/>, <img alt="HD Wallpaper | Background Image ID:719514" class="lazy-load" data-src="https://images.alphacoders.com/719/thumb-350-719514.png"/>, <img alt="" class="lazy-load" data-src="https://static.alphacoders.com/avatars/20-86009.jpg"/>, <img alt="HD Wallpaper | Background Image ID:969905" class="lazy-load" data-src="https://images2.alphacoders.com/969/thumb-350-969905.png"/>, <img alt="" class="lazy-load" data-src="https://static.alphacoders.com/avatars/20-141456.jpg"/>, <img alt="HD Wallpaper | Background Image ID:692882" class="lazy-load" data-src="https://images7.alphacoders.com/692/thumb-350-692882.jpg"/>, <img alt="" class="lazy-load" data-src="https://static.alphacoders.com/avatars/20-55041.jpg"/>, <img alt="HD Wallpaper | Background I
# ...

# %%
links =[]
for link in src:
    links.append(link.get('data-src'))
print(links)
# Out:
# [None, None, None, 'https://images.alphacoders.com/719/thumb-350-719514.png', 'https://static.alphacoders.com/avatars/20-86009.jpg', 'https://images2.alphacoders.com/969/thumb-350-969905.png', 'https://static.alphacoders.com/avatars/20-141456.jpg', 'https://images7.alphacoders.com/692/thumb-350-692882.jpg', 'https://static.alphacoders.com/avatars/20-55041.jpg', 'https://images.alphacoders.com/786/thumb-350-786887.png', 'https://static.alphacoders.com/avatars/20-86009.jpg', 'https://images6.alphacoders.com/785/thumb-350-785661.jpg', 'https://static.alphacoders.com/avatars/20-94732.jpg', 'https://images7.alphacoders.com/724/thumb-350-724419.png', 'https://static.alphacoders.com/avatars/20-86009.jpg', 'https://images.alphacoders.com/676/thumb-350-676565.png', 'https://static.alphacoders.com/avatars/20-55041.jpg', 'https://images3.alphacoders.com/715/thumb-350-715682.png', 'https://static.alphacoders.com/avatars/20-97828.jpg', 'https://images8.alphacoders.com/725/thumb-350-725683.png', '
# ...

# %%
import re
images_url=[]
for link in links:
    if type(link) is str and link.startswith('https://images'):
        print(type(link))
        print(link)
        print(re.sub('thumb-[0-9]+-','',link))
        images_url.append(re.sub('thumb-[0-9]+-','',link))
# Out:
# <class 'str'>
# https://images.alphacoders.com/719/thumb-350-719514.png
# https://images.alphacoders.com/719/719514.png
# <class 'str'>
# https://images2.alphacoders.com/969/thumb-350-969905.png
# https://images2.alphacoders.com/969/969905.png
# <class 'str'>
# https://images7.alphacoders.com/692/thumb-350-692882.jpg
# https://images7.alphacoders.com/692/692882.jpg
# <class 'str'>
# https://images.alphacoders.com/786/thumb-350-786887.png
# https://images.alphacoders.com/786/786887.png
# <class 'str'>
# https://images6.alphacoders.com/785/thumb-350-785661.jpg
# https://images6.alphacoders.com/785/785661.jpg
# <class 'str'>
# https://images7.alphacoders.com/724/thumb-350-724419.png
# https://images7.alphacoders.com/724/724419.png
# <class 'str'>
# https://images.alphacoders.com/676/thumb-350-676565.png
# https://images.alphacoders.com/676/676565.png
# <class 'str'>
# https://images3.alphacoders.com/715/thumb-350-715682.png
# https://images3.alphacoders.com/715/715682.png
# ...

# %%
# if not os.path.exists('./picture_fgo'):
#     os.mkdir('./picture')
count=0
for loop in images_url:
    responce_fgo = requests.get(loop) 
    print(responce_fgo)
    print(count)
    count+=1
    #with open(str('./picture/')+str(len())+str('.png'),'wb') as file:
       # file.write(responce.content)
# Out:
# <Response [200]>
# 0
# <Response [200]>
# 1
# <Response [200]>
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# <Response [200]>
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>
# 8
# <Response [200]>
# 9
# <Response [200]>
# 10
# <Response [200]>
# 11
# <Response [200]>
# 12
# <Response [200]>
# 13
# <Response [200]>
# 14
# <Response [200]>
# 15
# <Response [200]>
# 16
# <Response [200]>
# 17
# <Response [200]>
# 18
# <Response [200]>
# 19
# <Response [200]>
# 20
# <Response [200]>
# 21
# <Response [200]>
# 22
# <Response [200]>
# 23
# <Response [200]>
# 24
# <Response [200]>
# 25
# <Response [200]>
# 26
# <Response [200]>
# 27
# <Response [200]>
# 28
# <Response [200]>
# 29

# %%
print(len(images_url))
# Out:
# 30
